# %%
import pandas as pd

# %%
df = pd.read_csv("./data/crop_yield.csv")
df.shape
# Out:
# (19689, 9)

# %%
df[df.select_dtypes(include="number").columns].sample(5000).to_csv("./data/crop.csv", index=False)

# %%
df[df.select_dtypes(include="number").columns].sample(5000).iloc[:,:3].to_csv("./data/crop.csv", index=False)
